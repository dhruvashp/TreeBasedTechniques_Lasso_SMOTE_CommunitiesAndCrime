# %% [markdown]
# HW4
# 2b
# iii
#
# Here again we've used the entire training and test data (whole set in completion)
# The correlation matrix includes all features but excluded output from the matrix as the output is not numeric

# %%
import pandas as pd
import numpy as np

df_tot = pd.read_csv('aps_df_Final_Imputed_Whole.csv',index_col=0)
print(df_tot)

df = df_tot.drop(columns=['class'])  # dropping the output classification variable

correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#        class  aa_000    ab_000        ac_000       ad_000  ae_000  af_000  \
# 0          0   76698  0.000000  2.130706e+09   280.000000     0.0     0.0
# 1          0   33058  0.645959  0.000000e+00   638.509566     0.0     0.0
# 2          0   41040  0.644207  2.280000e+02   100.000000     0.0     0.0
# 3          0      12  0.000000  7.000000e+01    66.000000     0.0    10.0
# 4          0   60874  0.035666  1.368000e+03   458.000000     0.0     0.0
# ...      ...     ...       ...           ...          ...     ...     ...
# 75995      0   81852  0.709256  2.130706e+09   892.000000     0.0     0.0
# 75996      0      18  0.000000  5.200000e+01    46.000000     8.0    26.0
# 75997      0   79636  0.063588  1.670000e+03  1518.000000     0.0     0.0
# 75998      0     110  0.000000  3.600000e+01    32.000000     0.0     0.0
# 75999      0       8  0.000000  6.000000e+00     4.000000     2.0     2.0
#
#        ag_000  ag_001  ag_002  ...     ee_002    ee_003    ee_004    ee_005  \
# ...
